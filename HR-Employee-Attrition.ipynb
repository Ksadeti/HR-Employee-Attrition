# %% [markdown]
# # HR Analytics

# %%
# For data manipulation
import numpy as np
import pandas as pd

# For data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading dataset into a dataframe
df0 = pd.read_csv("HR-Employee-Attrition.csv")

# %%
# Displaying first few rows
df0.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
# Deleting redundant columns
redundant_columns = ['EmployeeCount', 'StandardHours', 'Over18']
df1 = df0.drop(columns=redundant_columns, inplace=False)

# %%
df1.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# ...

# %%
# Displaying all column names
df1.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# Renaming columns as needed
df2 = df1.rename(columns={'Age': 'Age',
    'Attrition': 'Attrition',
    'BusinessTravel': 'BusinessTravel',
    'DailyRate': 'DailyRate',
    'Department': 'Department',
    'DistanceFromHome': 'DistanceFromHome',
    'Education': 'Education',
    'EducationField': 'EducationField',
    'EmployeeNumber': 'EmployeeNumber',
    'EnvironmentSatisfaction': 'EnvironmentSatisfaction',
    'Gender': 'Gender',
    'HourlyRate': 'HourlyRate',
    'JobInvolvement': 'JobInvolvement',
    'JobLevel': 'JobLevel',
    'JobRole': 'JobRole',
    'JobSatisfaction': 'JobSatisfaction',
    'MaritalStatus': 'MaritalStatus',
    'MonthlyIncome': 'MonthlyIncome',
    'MonthlyRate': 'MonthlyRate',
    'NumCompaniesWorked': 'NumCompaniesWorked',
    'OverTime': 'Overtime',
    'PercentSalaryHike': 'PercentSalaryHike',
    'PerformanceRating': 'PerformanceRating',
    'RelationshipSatisfaction': 'RelationshipSatisfaction',
    'StockOptionLevel': 'StockOptionLevel',
    'TotalWorkingYears': 'TotalWorkingYears',
    'TrainingTimesLastYear': 'TrainingTimesLastYear',
    'WorkLifeBalance': 'WorkLifeBalance',
    'YearsAtCompany': 'YearsAtCompany',
    'YearsInCurrentRole': 'YearsInCurrentRole',
    'YearsSinceLastPromotion': 'YearsSinceLastPromotion',
    'YearsWithCurrManager': 'YearsWithCurrentManager'})

# Displaying all column names after the update
df1.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# Checking for duplicates
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values.

# %%
# Checking for missing values
df2.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Overtime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %% [markdown]
# There are no missing values

# %%
# Cleaning indivial columns
string_columns = df2.select_dtypes(include='object').columns

for column in string_columns:
    df2[column] = df2[column].str.strip()

# %%
# Binary Encoding of Categorical Variables, 'Attrition' and 'Overtime' 
df2['Attrition'] = df2['Attrition'].replace({'Yes': 1, 'No': 0})
df2['Overtime'] = df2['Overtime'].replace({'Yes': 1, 'No': 0})

# %%
# Removing NaN values
df2.dropna(inplace=True)

# %%
# Specifying the variables which I want to remove outliers
variables_to_check = ['Age', 'DailyRate','DistanceFromHome', 'Education', 'HourlyRate', 'JobInvolvement',
       'JobSatisfaction','MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 
       'RelationshipSatisfaction','StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrentManager']

# Function to remove outliers using IQR method
def remove_outliers_iqr(df2, variable):
    Q1 = df2[variable].quantile(0.25)
    Q3 = df2[variable].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data = df2[(df2[variable] >= lower_bound) & (df2[variable] <= upper_bound)]
    return data

# Looping through all specified variables and removing outliers
for var in variables_to_check:
    df3 = remove_outliers_iqr(df2, var)

# %% [markdown]
# ## Data Visualization

# %%
# Plotting a correlation map for all numeric variables
plt.figure(figsize=(50, 30))

# Explicitly set numeric_only=True to address the warning
correlation_matrix = df1.corr(numeric_only=True)

sns.heatmap(correlation_matrix, annot=True, cmap='crest')

plt.title('Correlation Map for Numeric Variables')

plt.show()

# %% [markdown]
# The correlation map illustrates the strength and direction of associations between numeric variables in the HR Analytics dataset. Strong positive correlations exist between Overtime and JobRole, and DistanceFromHome and Department, while the strongest negative correlation is observed between BusinessTravel and NumberOfCompaniesWorked. These findings reveal patterns and trends in the data, such as employees with higher education levels tending to earn higher incomes, and employees who travel for business or have worked for multiple companies being more likely to leave the company.

# %% [markdown]
# Double click on the above correlation map to zoom out.

# %%
# Countplot for 'Overtime'
sns.countplot(x='OverTime', data=df1)
plt.title('Count of Overtime')
plt.show()

# %%
# Countplot for 'MaritalStatus'
sns.countplot(x='MaritalStatus', data=df1)
plt.title('Marital Status')
plt.show()

# %%
# Countplot for 'JobRole'
plt.figure(figsize=(8, 6))
sns.countplot(x='JobRole', data=df1, order=df1['JobRole'].value_counts().index)
plt.title('Job Role')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Sales Representative stands out as the most sought-after position with over 300 openings, followed by Research Scientist, Laboratory Technician, and Manufacturing Director, each with around 250 openings. While Human Resources and Sales Director positions have the least openings, there are outliers like Healthcare Representative and Research Director with more job opportunities than the rest. The skewed nature of the distribution highlights a higher demand for certain job roles compared to others.

# %%
# Countplot for 'Gender'
sns.countplot(x='Gender', data=df1)
plt.title('Gender')
plt.show()

# %%
# Countplot for 'EducationField'
sns.countplot(x='EducationField', data=df1, order=df1['EducationField'].value_counts().index)
plt.title('Education Field')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Countplot for 'Department'
sns.countplot(x='Department', data=df1)
plt.title('Department')
plt.show()

# %%
# Countplot for 'BusinessTravel'
sns.countplot(x='BusinessTravel', data=df1)
plt.title('Business Travel')
plt.show()

# %%
# Boxplot for 'Overtime' vs 'Age'
plt.figure(figsize=(6, 2))
sns.boxplot(x='Overtime', y='Age', data=df1)
plt.title('Relation between Overtime and Age')
plt.show()

# %% [markdown]
# The boxplot reveals a positive correlation between age and overtime hours worked, indicating that older employees tend to work more overtime hours than younger employees. The median overtime hours worked increases with age, and there is greater variability in overtime hours among older employees compared to younger employees. Additionally, outliers are more prevalent among older employees, suggesting that some individuals work significantly different overtime hours compared to the rest of their age group.

# %%
# Boxplot for 'TotalWorkingYears'
plt.figure(figsize=(6, 2))
sns.boxplot(x='TotalWorkingYears', data=df1)
plt.title('Total Working Years')
plt.show()

# %% [markdown]
# The boxplot depicts the distribution of working years among a group of individuals. The median working years lie at 20, indicating that half of the group has worked for less than 20 years and the other half has worked for more than 20 years. The spread of working years is wide, with individuals having worked between 5 and 40 years. A few outliers exist, suggesting the presence of individuals with significantly shorter or longer working years compared to the majority of the group.

# %%
# Countplot for 'Education'
sns.countplot(x='Education', data=df1)
plt.title('Education Level')
plt.show()

# %% [markdown]
# The most common education level is Bachelor's degree, with a significant percentage of individuals holding this qualification. Master's degree and Associate's degree follow, while the least common levels are Some college and Less than high school. The distribution is skewed to the right, indicating that there are more individuals with lower education levels compared to those with higher education levels.

# %%
# Countplot for 'NumCompaniesWorked'
sns.countplot(x='NumCompaniesWorked', data=df1)
plt.title('Number of Companies Worked')
plt.show()

# %% [markdown]
# The majority of employees earn between \\$50,000 and \\$100,000, with a few outliers earning significantly less or more. The distribution is skewed to the right, indicating that there are more employees earning lower salaries than higher salaries.

# %%
# Boxplot for 'DistanceFromHome'
plt.figure(figsize=(6, 2))
sns.boxplot(x='DistanceFromHome', data=df1)
plt.title('Distance from Home')
plt.show()

# %% [markdown]
# The median distance from home lies at 5 miles, implying that half of the group lives closer than 5 miles from their home and the other half lives further away. The range of distances from home is extensive, with individuals living between 0.5 and 20 miles from their home. There are a few outliers, suggesting that a few individuals live significantly closer or further away from their home compared to the majority of the group.

# %% [markdown]
# ### Summary of results

# %% [markdown]
# The correlation map and visualizations provide valuable insights into the HR analytics dataset. Notably, strong positive correlations were found between Overtime and JobRole, as well as DistanceFromHome and Department. The distribution of Job Roles highlights a significant demand for Sales Representative positions. Boxplots reveal a positive correlation between age and overtime hours, indicating that older employees tend to work more overtime. The 'TotalWorkingYears' boxplot indicates a wide range of working years, with outliers suggesting variations in experience. Countplots for Education and NumCompaniesWorked depict employees' educational levels and experiences with different companies. The 'DistanceFromHome' boxplot shows a diverse distribution of distances from home.

# %% [markdown]
# ##### Key Findings:
#
# Sales Representative is the most sought-after job role, indicating a skewed demand for certain positions.
#
# The boxplot for 'Overtime vs. Age' suggests that older employees tend to work more overtime hours than younger employees.
#
# Education levels are skewed towards Bachelor's degrees, with fewer individuals having higher education levels.
#
# Most employees earn between \\$50,000 and \\$100,000, with a right-skewed distribution indicating more lower salaries.
#
# The boxplot for 'DistanceFromHome' shows a diverse range, with outliers suggesting some individuals live significantly closer or further away from their home compared to the majority.

# %% [markdown]
# #### Insights and Recommendations:
#
# HR can focus on managing workload, especially for older employees working overtime.
#
# Recruitment strategies should consider the high demand for certain job roles.
#
# Employee satisfaction studies could be conducted, considering factors like distance from home and education levels.
